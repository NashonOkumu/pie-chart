# %%
#importing matplotlib library
from matplotlib import pyplot as plt

# %%
#initialzing dataset
cars = ['AUDI', 'BMW', 'FORD',
        'TESLA', 'JAGUAR', 'MERCEDES']
  
data = [22, 19, 37, 28, 14, 43]

# %%
#creating a plot
fig=plt.figure(figsize=(10,8))
plt.pie(data, labels=cars)
# Out:
# ([<matplotlib.patches.Wedge at 0x2de9c4f95e0>,
# ...
#  [Text(1.0025872239031157, 0.4525691753381396, 'AUDI'),
#   Text(0.38395911549663314, 1.030812978976809, 'BMW'),
#   Text(-0.7276020368957271, 0.8249819852003976, 'FORD'),
#   Text(-1.0111231233979923, -0.4331628208074751, 'TESLA'),
#   Text(-0.3839591637524705, -1.0308129610023846, 'JAGUAR'),
#   Text(0.7433662738249084, -0.8108061315380339, 'MERCEDES')])
